# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ds_salaries.csv")
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.plot.scatter(x="job_title", y="salary_in_usd")
# Out:
# <Axes: xlabel='job_title', ylabel='salary_in_usd'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df["job_title"].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
df.groupby("job_title").mean("salary_in_usd").plot.bar(figsize=(20, 10))
# Out:
# <Axes: xlabel='job_title'>

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({'salary': [65, 75, 95, 110, 85]})

# Define conditions
conditions = [
    (df['salary'] < 70),
    (df['salary'] < 90),
    (df['salary'] >= 90)
]

# Define corresponding labels
labels = ['brokie', 'poor', 'average']

# Create new column
df['salary_group'] = np.select(conditions, labels, default='')

print(df)
# Out:
#    salary salary_group
# 0      65       brokie
# 1      75         poor
# 2      95      average
# 3     110      average
# 4      85         poor

# %%
df = pd.read_csv("ds_salaries.csv")
ax = df.groupby("job_title").mean("salary_in_usd")['salary_in_usd'].sort_values().plot.bar(figsize=(20, 10))
ax.set_xlabel('Job Title')
ax.set_ylabel('Salary in USD')
ax.set_title('Average Salary by Job Title')
plt.show()

# %%
ax = df.plot.scatter(x="job_title", y="salary_in_usd", figsize=(20, 10))
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel('Job Title')
ax.set_ylabel('Salary in USD')
ax.set_title('Salary Prediction')
plt.show()
# Out:
# /tmp/ipython-input-979450397.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
